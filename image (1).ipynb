# %%
import numpy as np
import pandas as pd
import cv2 as cv
# from google.colab.patches import cv2_imshow    
from skimage import io
from PIL import Image
import matplotlib.pylab as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-7b6400837e61> in <module>
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import cv2 as cv
#       4 # from google.colab.patches import cv2_imshow
#       5 from skimage import io
#
# ModuleNotFoundError: No module named 'cv2'

# %%
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
"https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
"https://placekitten.com/800/571"]
for url in urls:
    image = io.imread(url)   #BGR
    image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)  #RGB 
    final_frame = cv.hconcat((image, image_2))  
    cv2_imshow(final_frame)
print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=1600x552 at 0x7FBF3847FBD0>
# <PIL.Image.Image image mode=RGB size=1600x571 at 0x7FBF3847F450>
# <PIL.Image.Image image mode=RGB size=1600x571 at 0x7FBF3847FF10>

# %%
print(image.dtype)
print(image.shape[0])
print(image.shape[1])
print(image.shape[2])
# Out:
# uint8
# 571
# 800
# 3

# %%
gray_image= cv.cvtColor(image, cv.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=800x571 at 0x7FBF384B1C50>

# %%
im2= 255 - gray_image
cv2_imshow(im2)
# Out:
# <PIL.Image.Image image mode=L size=800x571 at 0x7FBF384B1E90>
